# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:\\Users\\Palmiere\\Documents\\Projetos\\Bradesco\\dados_Bradesco.xlsx")

# %%
df
# Out:
#                                       Unnamed: 0    1T07    2T07    3T07  \
# 0                                            NaN     NaN     NaN     NaN
# 1                                            NaN     NaN     NaN     NaN
# 2                               Rendas de Cartão   560.0   597.0   640.0
# 3                                 Conta-Corrente   529.0   535.0   540.0
# 4                           Operações de Crédito   422.0   445.0   495.0
# 5                        Administração de Fundos   334.0   345.0   376.0
# 6                                       Cobrança   204.0   211.0   217.0
# 7   Rendas de Serviços de Custódia e Corretagens    49.0    57.0    64.0
# 8         Tarifas de Administração de Consórcios    53.0    57.0    61.0
# 9                                   Arrecadações    70.0    66.0    63.0
# 10                                        Outras   237.0   201.0   205.0
# 11                                           NaN     NaN     NaN     NaN
# ...

# %%
# Deletando linhas e colunas vazias

# %%
df.isnull()
# Out:
#     Unnamed: 0   1T07   2T07   3T07   4T07   1T08   2T08   3T08   4T08   1T09  \
# 0         True   True   True   True   True   True   True   True   True   True
# 1         True   True   True   True   True   True   True   True   True   True
# 2        False  False  False  False  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# 5        False  False  False  False  False  False  False  False  False  False
# 6        False  False  False  False  False  False  False  False  False  False
# 7        False  False  False  False  False  False  False  False  False  False
# 8        False  False  False  False  False  False  False  False  False  False
# 9        False  False  False  False  False  False  False  False  False  False
# 10       False  False  False  False  False  False  False  False  False  False
# ...

# %%
from numpy import nan

# %%
df.dropna(how="all", inplace=True)

# %%
df
# Out:
#                                       Unnamed: 0    1T07    2T07    3T07  \
# 2                               Rendas de Cartão   560.0   597.0   640.0
# 3                                 Conta-Corrente   529.0   535.0   540.0
# 4                           Operações de Crédito   422.0   445.0   495.0
# 5                        Administração de Fundos   334.0   345.0   376.0
# 6                                       Cobrança   204.0   211.0   217.0
# 7   Rendas de Serviços de Custódia e Corretagens    49.0    57.0    64.0
# 8         Tarifas de Administração de Consórcios    53.0    57.0    61.0
# 9                                   Arrecadações    70.0    66.0    63.0
# 10                                        Outras   237.0   201.0   205.0
# 12                                         TOTAL  2458.0  2514.0  2661.0
#
#       4T07    1T08    2T08    3T08    4T08    1T09  ...  Unnamed: 127  \
# 2    706.0   687.0   720.0   781.0   877.0   834.0  ...           NaN
# ...

# %%
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#                                       Unnamed: 0    1T07    2T07    3T07  \
# 2                               Rendas de Cartão   560.0   597.0   640.0
# 3                                 Conta-Corrente   529.0   535.0   540.0
# 4                           Operações de Crédito   422.0   445.0   495.0
# 5                        Administração de Fundos   334.0   345.0   376.0
# 6                                       Cobrança   204.0   211.0   217.0
# 7   Rendas de Serviços de Custódia e Corretagens    49.0    57.0    64.0
# 8         Tarifas de Administração de Consórcios    53.0    57.0    61.0
# 9                                   Arrecadações    70.0    66.0    63.0
# 10                                        Outras   237.0   201.0   205.0
# 12                                         TOTAL  2458.0  2514.0  2661.0
#
#       4T07    1T08    2T08    3T08    4T08    1T09  ...    2T20    3T20  \
# 2    706.0   687.0   720.0   781.0   877.0   834.0  ...  2352.0  2530.0
# ...

# %%
df.isnull()
# Out:
#     Unnamed: 0   1T07   2T07   3T07   4T07   1T08   2T08   3T08   4T08   1T09  \
# 2        False  False  False  False  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# 5        False  False  False  False  False  False  False  False  False  False
# 6        False  False  False  False  False  False  False  False  False  False
# 7        False  False  False  False  False  False  False  False  False  False
# 8        False  False  False  False  False  False  False  False  False  False
# 9        False  False  False  False  False  False  False  False  False  False
# 10       False  False  False  False  False  False  False  False  False  False
# 12       False  False  False  False  False  False  False  False  False  False
#
#     ...   2T20   3T20   4T20   1T21   2T21   3T21   4T21   1T22   2T22   3T22
# ...

# %%
# Operação de matrix transposta para corrigir o dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '1T07', '2T07', '3T07', '4T07', '1T08', '2T08', '3T08',
#        '4T08', '1T09', '2T09', '3T09', '4T09', '1T10', '2T10', '3T10', '4T10',
#        '1T11', '2T11', '3T11', '4T11', '1T12', '2T12', '3T12', '4T12', '1T13',
#        '2T13', '3T13', '4T13', '1T14', '2T14', '3T14', '4T14', '1T15', '2T15',
#        '3T15', '4T15', '1T16', '2T16', '3T16', '4T16', '1T17', '2T17', '3T17',
#        '4T17', '1T18', '2T18', '3T18', '4T18', '1T19', '2T19', '3T19', '4T19',
#        '1T20', '2T20', '3T20', '4T20', '1T21', '2T21', '3T21', '4T21', '1T22',
#        '2T22', '3T22'],
#       dtype='object')

# %%
df = df.rename(columns={'Unnamed: 0':'Periodo'})

# %%
df.columns
# Out:
# Index(['Periodo', '1T07', '2T07', '3T07', '4T07', '1T08', '2T08', '3T08',
#        '4T08', '1T09', '2T09', '3T09', '4T09', '1T10', '2T10', '3T10', '4T10',
#        '1T11', '2T11', '3T11', '4T11', '1T12', '2T12', '3T12', '4T12', '1T13',
#        '2T13', '3T13', '4T13', '1T14', '2T14', '3T14', '4T14', '1T15', '2T15',
#        '3T15', '4T15', '1T16', '2T16', '3T16', '4T16', '1T17', '2T17', '3T17',
#        '4T17', '1T18', '2T18', '3T18', '4T18', '1T19', '2T19', '3T19', '4T19',
#        '1T20', '2T20', '3T20', '4T20', '1T21', '2T21', '3T21', '4T21', '1T22',
#        '2T22', '3T22'],
#       dtype='object')

# %%
df = (df.set_index('Periodo').T)

# %%
df
# Out:
# Periodo  Rendas de Cartão  Conta-Corrente  Operações de Crédito  \
# 1T07                560.0           529.0                 422.0
# 2T07                597.0           535.0                 445.0
# 3T07                640.0           540.0                 495.0
# 4T07                706.0           556.0                 503.0
# 1T08                687.0           521.0                 482.0
# 2T08                720.0           520.0                 387.0
# 3T08                781.0           496.0                 337.0
# 4T08                877.0           492.0                 304.0
# 1T09                834.0           487.0                 366.0
# 2T09                851.0           551.0                 362.0
# 3T09                785.0           539.0                 390.0
# 4T09                953.0           543.0                 405.0
# 1T10                972.0           542.0                 390.0
# 2T10                993.0           577.0                 439.0
# ...

# %%
df.columns
# Out:
# Index(['Rendas de Cartão', 'Conta-Corrente', 'Operações de Crédito',
#        'Administração de Fundos', 'Cobrança',
#        'Rendas de Serviços de Custódia e Corretagens',
#        'Tarifas de Administração de Consórcios', 'Arrecadações', 'Outras',
#        'TOTAL'],
#       dtype='object', name='Periodo')

# %%
df.index
# Out:
# Index(['1T07', '2T07', '3T07', '4T07', '1T08', '2T08', '3T08', '4T08', '1T09',
#        '2T09', '3T09', '4T09', '1T10', '2T10', '3T10', '4T10', '1T11', '2T11',
#        '3T11', '4T11', '1T12', '2T12', '3T12', '4T12', '1T13', '2T13', '3T13',
#        '4T13', '1T14', '2T14', '3T14', '4T14', '1T15', '2T15', '3T15', '4T15',
#        '1T16', '2T16', '3T16', '4T16', '1T17', '2T17', '3T17', '4T17', '1T18',
#        '2T18', '3T18', '4T18', '1T19', '2T19', '3T19', '4T19', '1T20', '2T20',
#        '3T20', '4T20', '1T21', '2T21', '3T21', '4T21', '1T22', '2T22', '3T22'],
#       dtype='object')

# %%
# Criando arquivo CSV do dataframe

# %%
df.to_csv('C:\\Users\\Palmiere\\Documents\\Projetos\\Bradesco\\bradesco.csv', header= True, index= True, encoding='utf-8')
